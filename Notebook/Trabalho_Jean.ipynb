# %% [markdown]
# # Informações dos testes no MOA
#
# Algoritmos Geradores para classificação:
#     * SEA
#     * Agrawal
#     * Assets
#
# Algoritmos Classificadores:
#     * HoeffdingTree
#     * Naive Bayes
#     * kNN
#     * OzaBagAdwin

# %% [markdown]
# # HoeffdingTree + SEAGenerator:
# ```java
# EvaluatePrequential -l trees.HoeffdingTree -s (ConceptDriftStream -s (generators.SEAGenerator -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 4 -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 3 -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 2 -b) -d (generators.SEAGenerator -b) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # NaiveBayes + SEAGenerator:
# ```java
# EvaluatePrequential -l bayes.NaiveBayes -s (ConceptDriftStream -s (generators.SEAGenerator -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 4 -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 3 -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 2 -b) -d (generators.SEAGenerator -b) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # kNN + SEAGenerator:
# ```java
# EvaluatePrequential -l lazy.kNN -s (ConceptDriftStream -s (generators.SEAGenerator -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 4 -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 3 -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 2 -b) -d (generators.SEAGenerator -b) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # OzaBagAdwin + SEAGenerator
# ```java
# EvaluatePrequential -l meta.OzaBagAdwin -s (ConceptDriftStream -s (generators.SEAGenerator -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 4 -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 3 -b) -d (ConceptDriftStream -s (generators.SEAGenerator -f 2 -b) -d (generators.SEAGenerator -b) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # HoeffdingTree + AgrawalGenerator:
# ```java
# EvaluatePrequential -l trees.HoeffdingTree -s (ConceptDriftStream -s (generators.AgrawalGenerator -f 5 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 4 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 3 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 2 -b) -d (generators.AgrawalGenerator -b) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # NaiveBayes + AgrawalGenerator:
# ```java
# EvaluatePrequential -l bayes.NaiveBayes -s (ConceptDriftStream -s (generators.AgrawalGenerator -f 5 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 4 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 3 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 2 -b) -d (generators.AgrawalGenerator -b) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # kNN + AgrawalGenerator:
# ```java
# EvaluatePrequential -l lazy.kNN -s (ConceptDriftStream -s (generators.AgrawalGenerator -f 5 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 4 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 3 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 2 -b) -d (generators.AgrawalGenerator -b) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # OzaBagAdwin + AgrawalGenerator:
# ```java
# EvaluatePrequential -l meta.OzaBagAdwin -s (ConceptDriftStream -s (generators.AgrawalGenerator -f 5 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 4 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 3 -b) -d (ConceptDriftStream -s (generators.AgrawalGenerator -f 2 -b) -d (generators.AgrawalGenerator -b) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # HoeffdingTree + AssetNegotiationGenerator:
# ```java
# EvaluatePrequential -l trees.HoeffdingTree -s (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 5) -d (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 4) -d (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 3) -d (ConceptDriftStream -s generators.AssetNegotiationGenerator -d (generators.AssetNegotiationGenerator -f 2) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # NaiveBayes + AssetNegotiationGenerator:
# ```java
# EvaluatePrequential -l bayes.NaiveBayes -s (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 5) -d (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 4) -d (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 3) -d (ConceptDriftStream -s generators.AssetNegotiationGenerator -d (generators.AssetNegotiationGenerator -f 2) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # kNN + AssetNegotiationGenerator:
# ```java
# EvaluatePrequential -l lazy.kNN -s (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 5) -d (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 4) -d (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 3) -d (ConceptDriftStream -s generators.AssetNegotiationGenerator -d (generators.AssetNegotiationGenerator -f 2) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```
#
# # OzaBagAdwin + AssetNegotiationGenerator:
# ```java
# EvaluatePrequential -l meta.OzaBagAdwin -s (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 5) -d (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 4) -d (ConceptDriftStream -s (generators.AssetNegotiationGenerator -f 3) -d (ConceptDriftStream -s generators.AssetNegotiationGenerator -d (generators.AssetNegotiationGenerator -f 2) -p 200000) -p 200000) -p 200000) -p 200000) -i 1000000 -f 1000
# ```

# %%
# Importando as bibliotecas.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Carregando as bases do gerador AgrawalGenerator.
df_Hoeffding_Agrawal = pd.read_csv('../AgrawalGenerator/HoeffdingTree_38,71s.txt')
df_Naive_Agrawal = pd.read_csv('../AgrawalGenerator/NaiveBayes_2,91s.txt')
df_kNN_Agrawal = pd.read_csv('../AgrawalGenerator/kNN_4m7s.txt')
df_Oza_Agrawal = pd.read_csv('../AgrawalGenerator/OzaBagAdwin_2m56s.txt')

# %%
df_Hoeffding_Agrawal.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                    1000.000000                    1000.000000
# mean                   500500.000000                      13.628539
# std                    288819.436096                      11.444667
# min                      1000.000000                       0.028894
# 25%                    250750.000000                       3.473962
# 50%                    500500.000000                      10.357248
# 75%                    750250.000000                      22.634799
# max                   1000000.000000                      38.651274
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+03           1000.000000
# mean             5.812244e-06         500500.000000
# std              6.559958e-06         288819.436096
# min              3.516240e-11           1000.000000
# 25%              4.778117e-07         250750.000000
# 50%              2.656823e-06         500500.000000
# 75%              1.000477e-05         750250.000000
# max              2.266253e-05        1000000.000000
#
#        classifications correct (percent)  Kappa Statistic (percent)  \
# count                         1000.00000                1000.000000
# mean                            66.05190                  32.103869
# std                              7.14921                  14.298275
# min                             47.80000                  -4.400000
# 25%                             61.30000                  22.600000
# 50%                             67.50000                  35.000000
# 75%                             71.30000                  42.600000
# max                             78.90000                  57.800000
#
#        Kappa Temporal Statistic (percent)  model training instances  \
# count                         1000.000000               1000.000000
# mean                            66.010154             500500.000000
# std                              7.189705             288819.436096
# min                             47.800000               1000.000000
# 25%                             61.300000             250750.000000
# 50%                             67.500000             500500.000000
# 75%                             71.300000             750250.000000
# max                             78.900000            1000000.000000
#
#        model serialized size (bytes)  tree size (nodes)  tree size (leaves)  \
# count                   1.000000e+03        1000.000000         1000.000000
# mean                    1.734235e+06         599.535000          391.759000
# std                     1.031157e+06         364.240533          232.228549
# min                     4.704000e+03           1.000000            1.000000
# 25%                     8.748920e+05         303.500000          197.750000
# 50%                     1.631160e+06         553.500000          373.000000
# 75%                     2.716474e+06         935.000000          611.000000
# max                     3.335560e+06        1212.000000          757.000000
#
#        active learning leaves   tree depth  active leaf byte size estimate  \
# count             1000.000000  1000.000000                     1000.000000
# mean               391.759000     9.063000                        4.330769
# std                232.228549     2.276447                      136.950935
# min                  1.000000     0.000000                        0.000000
# 25%                197.750000     7.000000                        0.000000
# 50%                373.000000    10.000000                        0.000000
# 75%                611.000000    11.000000                        0.000000
# max                757.000000    12.000000                     4330.768824
#
#        inactive leaf byte size estimate  byte size estimate overhead
# count                            1000.0                  1000.000000
# mean                                0.0                     1.000017
# std                                 0.0                     0.000551
# min                                 0.0                     1.000000
# 25%                                 0.0                     1.000000
# 50%                                 0.0                     1.000000
# 75%                                 0.0                     1.000000
# max                                 0.0                     1.017438

# %%
df_Naive_Agrawal.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                    1000.000000                    1000.000000
# mean                   500500.000000                       1.375160
# std                    288819.436096                       0.836142
# min                      1000.000000                       0.007260
# 25%                    250750.000000                       0.644208
# 50%                    500500.000000                       1.324336
# 75%                    750250.000000                       2.093806
# max                   1000000.000000                       2.913322
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+03           1000.000000
# mean             1.642165e-09         500500.000000
# std              9.984894e-10         288819.436096
# min              8.669959e-12           1000.000000
# 25%              7.692886e-10         250750.000000
# 50%              1.581473e-09         500500.000000
# 75%              2.500344e-09         750250.000000
# max              3.478980e-09        1000000.000000
#
#        classifications correct (percent)  Kappa Statistic (percent)  \
# count                          1000.0000                1000.000000
# mean                             59.4361                  18.872236
# std                               6.4333                  12.866541
# min                              46.5000                  -7.000000
# 25%                              53.7000                   7.400000
# 50%                              59.7000                  19.400000
# 75%                              65.1000                  30.200000
# max                              71.4000                  42.800000
#
#        Kappa Temporal Statistic (percent)  model training instances  \
# count                         1000.000000               1000.000000
# mean                            59.388714             500500.000000
# std                              6.468940             288819.436096
# min                             43.184422               1000.000000
# 25%                             53.600000             250750.000000
# 50%                             59.600000             500500.000000
# 75%                             65.100000             750250.000000
# max                             71.400000            1000000.000000
#
#        model serialized size (bytes)
# count                         1000.0
# mean                          4616.0
# std                              0.0
# min                           4616.0
# 25%                           4616.0
# 50%                           4616.0
# 75%                           4616.0
# max                           4616.0

# %%
df_kNN_Agrawal.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                    1000.000000                    1000.000000
# mean                   500500.000000                     126.851919
# std                    288819.436096                      72.464398
# min                      1000.000000                       0.181570
# 25%                    250750.000000                      63.324142
# 50%                    500500.000000                     131.442041
# 75%                    750250.000000                     189.614930
# max                   1000000.000000                     247.378995
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+03           1000.000000
# mean             2.158356e-05         500500.000000
# std              1.233328e-05         288819.436096
# min              3.086613e-08           1000.000000
# 25%              1.076938e-05         250750.000000
# 50%              2.236404e-05         500500.000000
# 75%              3.226585e-05         750250.000000
# max              4.209808e-05        1000000.000000
#
#        classifications correct (percent)  Kappa Statistic (percent)  \
# count                        1000.000000                1000.000000
# mean                           60.937200                  21.874513
# std                             8.537985                  17.075914
# min                            49.900000                  -0.200000
# 25%                            54.900000                   9.800000
# 50%                            56.900000                  13.800000
# 75%                            63.325000                  26.650000
# max                            80.000000                  60.000000
#
#        Kappa Temporal Statistic (percent)  model training instances  \
# count                         1000.000000               1000.000000
# mean                            60.891379             500500.000000
# std                              8.567252             288819.436096
# min                             43.298969               1000.000000
# 25%                             54.800000             250750.000000
# 50%                             56.900000             500500.000000
# 75%                             63.303571             750250.000000
# max                             80.000000            1000000.000000
#
#        model serialized size (bytes)
# count                    1000.000000
# mean                   657809.744000
# std                       501.793443
# min                    657112.000000
# 25%                    657912.000000
# 50%                    657912.000000
# 75%                    657912.000000
# max                    660656.000000

# %%
df_Oza_Agrawal.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                    1000.000000                    1000.000000
# mean                   500500.000000                      82.278109
# std                    288819.436096                      50.891723
# min                      1000.000000                       0.061014
# 25%                    250750.000000                      38.765689
# 50%                    500500.000000                      80.919532
# 75%                    750250.000000                     126.402861
# max                   1000000.000000                     175.747531
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+03           1000.000000
# mean             1.175426e-04         500500.000000
# std              7.818861e-05         288819.436096
# min              2.199066e-09           1000.000000
# 25%              5.048050e-05         250750.000000
# 50%              1.166005e-04         500500.000000
# 75%              1.793284e-04         750250.000000
# max              2.677582e-04        1000000.000000
#
#        classifications correct (percent)  Kappa Statistic (percent)  \
# count                        1000.000000                1000.000000
# mean                           84.327800                  68.655609
# std                            10.204945                  20.409896
# min                            53.600000                   7.192204
# 25%                            76.675000                  53.350000
# 50%                            81.650000                  63.300000
# 75%                            95.025000                  90.050000
# max                            98.600000                  97.200000
#
#        Kappa Temporal Statistic (percent)  model training instances  \
# count                         1000.000000               1000.000000
# mean                            84.294332             500500.000000
# std                             10.268744             288819.436096
# min                             52.517162               1000.000000
# 25%                             76.675000             250750.000000
# 50%                             81.650000             500500.000000
# 75%                             95.025000             750250.000000
# max                             98.600000            1000000.000000
#
#        model serialized size (bytes)  ensemble size  \
# count                   1.000000e+03         1000.0
# mean                    4.218966e+06           10.0
# std                     2.892020e+06            0.0
# min                     1.352080e+05           10.0
# 25%                     1.753716e+06           10.0
# 50%                     2.847624e+06           10.0
# 75%                     6.890682e+06           10.0
# max                     1.038548e+07           10.0
#
#                      ...                  [avg] active learning leaves  \
# count                ...                                   1000.000000
# mean                 ...                                     95.495500
# std                  ...                                     66.953604
# min                  ...                                      1.000000
# 25%                  ...                                     38.200000
# 50%                  ...                                     64.350000
# 75%                  ...                                    156.425000
# max                  ...                                    236.500000
#
#        [err] active learning leaves  [avg] tree depth  [err] tree depth  \
# count                   1000.000000       1000.000000       1000.000000
# mean                      14.077635          4.780900          0.288395
# std                       11.922143          1.078429          0.177573
# min                        0.000000          0.000000          0.000000
# 25%                        4.017183          4.100000          0.152753
# 50%                       10.001333          5.000000          0.221108
# 75%                       22.970341          5.500000          0.427200
# max                       45.576566          6.400000          0.979796
#
#        [avg] active leaf byte size estimate  \
# count                                1000.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
#        [err] active leaf byte size estimate  \
# count                                1000.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
#        [avg] inactive leaf byte size estimate  \
# count                                  1000.0
# mean                                      0.0
# std                                       0.0
# min                                       0.0
# 25%                                       0.0
# 50%                                       0.0
# 75%                                       0.0
# max                                       0.0
#
#        [err] inactive leaf byte size estimate  \
# count                                  1000.0
# mean                                      0.0
# std                                       0.0
# min                                       0.0
# 25%                                       0.0
# 50%                                       0.0
# 75%                                       0.0
# max                                       0.0
#
#        [avg] byte size estimate overhead  [err] byte size estimate overhead
# count                             1000.0                             1000.0
# mean                                 1.0                                0.0
# std                                  0.0                                0.0
# min                                  1.0                                0.0
# 25%                                  1.0                                0.0
# 50%                                  1.0                                0.0
# 75%                                  1.0                                0.0
# max                                  1.0                                0.0
#
# [8 rows x 28 columns]

# %%
# Plotando o gráfico do gerador AgrawalGenerator.
plt.figure(figsize=(20,10))
plt.plot(df_Hoeffding_Agrawal['learning evaluation instances'], df_Hoeffding_Agrawal['classifications correct (percent)'], label='HoeffdingTree')
plt.plot(df_Naive_Agrawal['learning evaluation instances'], df_Naive_Agrawal['classifications correct (percent)'], label='NaiveBayes')
plt.plot(df_kNN_Agrawal['learning evaluation instances'], df_kNN_Agrawal['classifications correct (percent)'], label='kNN')
plt.plot(df_Oza_Agrawal['learning evaluation instances'], df_Oza_Agrawal['classifications correct (percent)'], label='OzaBagAdwin')
plt.axvspan(180000, 220000, color='red', alpha=0.5)
plt.axvspan(380000, 420000, color='red', alpha=0.5)
plt.axvspan(580000, 620000, color='red', alpha=0.5)
plt.axvspan(780000, 820000, color='red', alpha=0.5)
plt.xlim(0, 1000000)

# Add the legend with some customizations.
legend = plt.legend(loc='lower left', shadow=True)

# The frame is matplotlib.patches.Rectangle instance surrounding the legend.
frame = legend.get_frame()
frame.set_facecolor('0.90')

# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
    
for label in legend.get_lines():
    label.set_linewidth(1.5)

# Plot chart.
plt.show()

# %%
#Carregando as bases do gerador AssetNegotiationNegotiator.
df_Hoeffding_Asset = pd.read_csv('../AssetNegotiationGenerator/HoeffdingTree_1m12s.txt')
df_Naive_Asset = pd.read_csv('../AssetNegotiationGenerator/NaiveBayes_43,28s.txt')
df_kNN_Asset = pd.read_csv('../AssetNegotiationGenerator/kNN_3m10s.txt')
df_Oza_Asset = pd.read_csv('../AssetNegotiationGenerator/OzaBagAdwin_2m49s.txt')
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                    1000.000000                    1000.000000
# mean                   500500.000000                      30.845876
# std                    288819.436096                      19.736318
# min                      1000.000000                       0.096612
# 25%                    250750.000000                      13.871425
# 50%                    500500.000000                      29.065560
# 75%                    750250.000000                      45.474151
# max                   1000000.000000                      72.083714
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+03           1000.000000
# mean             8.240415e-06         500500.000000
# std              8.838480e-06         288819.436096
# min              3.359147e-11           1000.000000
# 25%              8.082648e-07         250750.000000
# 50%              5.136914e-06         500500.000000
# 75%              1.285048e-05         750250.000000
# max              3.209666e-05        1000000.000000
#
#        classifications correct (percent)  Kappa Statistic (percent)  \
# count                        1000.000000                1000.000000
# mean                           92.954800                  85.908341
# std                             4.779071                   9.556406
# min                            49.500000                  -0.806452
# 25%                            92.900000                  85.804003
# 50%                            93.600000                  87.203378
# 75%                            94.400000                  88.799418
# max                            96.600000                  93.199592
#
#        Kappa Temporal Statistic (percent)  Kappa M Statistic (percent)  \
# count                         1000.000000                  1000.000000
# mean                            92.185755                    85.730613
# std                              5.413919                     9.759368
# min                             45.048966                    -7.675906
# 25%                             92.125123                    85.656566
# 50%                             92.981509                    87.096774
# 75%                             93.834295                    88.627309
# max                             96.398305                    93.032787
#
#        model training instances  model serialized size (bytes)  \
# count               1000.000000                   1.000000e+03
# mean              500500.000000                   1.455727e+06
# std               288819.436096                   9.926353e+05
# min                 1000.000000                   1.344000e+03
# 25%               250750.000000                   3.697940e+05
# 50%               500500.000000                   1.540164e+06
# 75%               750250.000000                   2.494516e+06
# max              1000000.000000                   2.943752e+06
#
#        tree size (nodes)  tree size (leaves)  active learning leaves  \
# count         1000.00000         1000.000000             1000.000000
# mean          1061.86900          911.330000              911.330000
# std            733.76185          624.414595              624.414595
# min              9.00000            8.000000                8.000000
# 25%            276.00000          239.250000              239.250000
# 50%           1091.00000          944.000000              944.000000
# 75%           1814.00000         1552.000000             1552.000000
# max           2149.00000         1825.000000             1825.000000
#
#         tree depth  active leaf byte size estimate  \
# count  1000.000000                     1000.000000
# mean      4.959000                        1.592956
# std       0.345599                       50.373680
# min       1.000000                        0.000000
# 25%       5.000000                        0.000000
# 50%       5.000000                        0.000000
# 75%       5.000000                        0.000000
# max       5.000000                     1592.955616
#
#        inactive leaf byte size estimate  byte size estimate overhead
# count                            1000.0                  1000.000000
# mean                                0.0                     1.000013
# std                                 0.0                     0.000398
# min                                 0.0                     1.000000
# 25%                                 0.0                     1.000000
# 50%                                 0.0                     1.000000
# 75%                                 0.0                     1.000000
# max                                 0.0                     1.012592

# %%
df_Hoeffding_Asset.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                    1000.000000                    1000.000000
# mean                   500500.000000                      30.845876
# std                    288819.436096                      19.736318
# min                      1000.000000                       0.096612
# 25%                    250750.000000                      13.871425
# 50%                    500500.000000                      29.065560
# 75%                    750250.000000                      45.474151
# max                   1000000.000000                      72.083714
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+03           1000.000000
# mean             8.240415e-06         500500.000000
# std              8.838480e-06         288819.436096
# min              3.359147e-11           1000.000000
# 25%              8.082648e-07         250750.000000
# 50%              5.136914e-06         500500.000000
# 75%              1.285048e-05         750250.000000
# max              3.209666e-05        1000000.000000
#
#        classifications correct (percent)  Kappa Statistic (percent)  \
# count                        1000.000000                1000.000000
# mean                           92.954800                  85.908341
# std                             4.779071                   9.556406
# min                            49.500000                  -0.806452
# 25%                            92.900000                  85.804003
# 50%                            93.600000                  87.203378
# 75%                            94.400000                  88.799418
# max                            96.600000                  93.199592
#
#        Kappa Temporal Statistic (percent)  Kappa M Statistic (percent)  \
# count                         1000.000000                  1000.000000
# mean                            92.185755                    85.730613
# std                              5.413919                     9.759368
# min                             45.048966                    -7.675906
# 25%                             92.125123                    85.656566
# 50%                             92.981509                    87.096774
# 75%                             93.834295                    88.627309
# max                             96.398305                    93.032787
#
#        model training instances  model serialized size (bytes)  \
# count               1000.000000                   1.000000e+03
# mean              500500.000000                   1.455727e+06
# std               288819.436096                   9.926353e+05
# min                 1000.000000                   1.344000e+03
# 25%               250750.000000                   3.697940e+05
# 50%               500500.000000                   1.540164e+06
# 75%               750250.000000                   2.494516e+06
# max              1000000.000000                   2.943752e+06
#
#        tree size (nodes)  tree size (leaves)  active learning leaves  \
# count         1000.00000         1000.000000             1000.000000
# mean          1061.86900          911.330000              911.330000
# std            733.76185          624.414595              624.414595
describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                    1000.000000                    1000.000000
# mean                   500500.000000                      78.120719
# std                    288819.436096                      48.570428
# min                      1000.000000                       0.093680
# 25%                    250750.000000                      36.315671
# 50%                    500500.000000                      74.409249
# 75%                    750250.000000                     117.265606
# max                   1000000.000000                     169.257769
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+03           1000.000000
# mean             6.482896e-05         500500.000000
# std              5.082220e-05         288819.436096
# min              3.500511e-09           1000.000000
# 25%              2.245875e-05         250750.000000
# 50%              5.080334e-05         500500.000000
# 75%              1.031061e-04         750250.000000
# max              1.653906e-04        1000000.000000
#
#        classifications correct (percent)  Kappa Statistic (percent)  \
# count                        1000.000000                1000.000000
# mean                           94.625100                  89.250374
# std                             1.143691                   2.286394
# min                            81.500000                  63.000000
# 25%                            94.200000                  88.399617
# 50%                            94.800000                  89.597399
# 75%                            95.200000                  90.400192
# max                            97.200000                  94.400000
#
#        Kappa Temporal Statistic (percent)  Kappa M Statistic (percent)  \
# count                         1000.000000                  1000.000000
# mean                            94.040080                    89.119136
# std                              1.428748                     2.363367
# min                             77.411477                    62.321792
# 25%                             93.497758                    88.187373
# 50%                             94.218098                    89.378758
# 75%                             94.749794                    90.342052
# max                             97.033898                    94.297352
#
#        model training instances  model serialized size (bytes)  \
# count               1000.000000                   1.000000e+03
# mean              500500.000000                   3.166510e+06
# std               288819.436096                   1.838784e+06
# min                 1000.000000                   1.091680e+05
# 25%               250750.000000                   2.365542e+06
# 50%               500500.000000                   3.193804e+06
# 75%               750250.000000                   3.426874e+06
# max              1000000.000000                   8.289288e+06
#
#                      ...                  [avg] active learning leaves  \
# count                ...                                    1000.00000
# mean                 ...                                     189.97770
# std                  ...                                     115.35474
# min                  ...                                       1.00000
# 25%                  ...                                     147.17500
# 50%                  ...                                     187.00000
# 75%                  ...                                     202.90000
# max                  ...                                     498.80000
#
#        [err] active learning leaves  [avg] tree depth  [err] tree depth  \
# count                   1000.000000       1000.000000       1000.000000
# mean                      18.639496          4.696900          0.027865
# std                       19.489280          0.822506          0.087478
# min                        0.000000          0.000000          0.000000
# 25%                        1.483240          5.000000          0.000000
# 50%                        6.308372          5.000000          0.000000
# 75%                       43.272486          5.000000          0.000000
# max                       66.518076          5.000000          0.666667
#
#        [avg] active leaf byte size estimate  \
# count                                1000.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
#        [err] active leaf byte size estimate  \
# count                                1000.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
#        [avg] inactive leaf byte size estimate  \
# count                                  1000.0
# mean                                      0.0
# std                                       0.0
# min                                       0.0
# 25%                                       0.0
# 50%                                       0.0
# 75%                                       0.0
# max                                       0.0
#
#        [err] inactive leaf byte size estimate  \
# count                                  1000.0
# mean                                      0.0
# std                                       0.0
# min                                       0.0
# 25%                                       0.0
# 50%                                       0.0
# 75%                                       0.0
# max                                       0.0
#
#        [avg] byte size estimate overhead  [err] byte size estimate overhead
# count                             1000.0                             1000.0
# mean                                 1.0                                0.0
# std                                  0.0                                0.0
# min                                  1.0                                0.0
# 25%                                  1.0                                0.0
# 50%                                  1.0                                0.0
# 75%                                  1.0                                0.0
# max                                  1.0                                0.0
#
# [8 rows x 29 columns]

# %%
# Plotando o gráfico do gerador AssetNegotiationNegotiator.
plt.figure(figsize=(20,10))
plt.plot(df_Hoeffding_Asset['learning evaluation instances'], df_Hoeffding_Asset['classifications correct (percent)'], label='HoeffdingTree')
plt.plot(df_Naive_Asset['learning evaluation instances'], df_Naive_Asset['classifications correct (percent)'], label='NaiveBayes')
plt.plot(df_kNN_Asset['learning evaluation instances'], df_kNN_Asset['classifications correct (percent)'], label='kNN')
plt.plot(df_Oza_Asset['learning evaluation instances'], df_Oza_Asset['classifications correct (percent)'], label='OzaBagAdwin')
plt.axvspan(180000, 220000, color='red', alpha=0.5)
plt.axvspan(380000, 420000, color='red', alpha=0.5)
plt.axvspan(580000, 620000, color='red', alpha=0.5)
plt.axvspan(780000, 820000, color='red', alpha=0.5)
plt.xlim(0, 1000000)

# Add the legend with some customizations.
legend = plt.legend(loc='lower left', shadow=True)

# The frame is matplotlib.patches.Rectangle instance surrounding the legend.
frame = legend.get_frame()
frame.set_facecolor('0.90')

# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
    
for label in legend.get_lines():
    label.set_linewidth(1.5)

# Plot chart.
plt.show()

# %%
#Carregando as bases do gerador SEAGenerator.
df_Hoeffding_SEA = pd.read_csv('../SEAGenerator/HoeffdingTree_10,15s.txt')
df_Naive_SEA = pd.read_csv('../SEAGenerator/NaiveBayes_1,83s.txt')
df_kNN_SEA = pd.read_csv('../SEAGenerator/kNN_1m41s.txt')
df_Oza_SEA = pd.read_csv('../SEAGenerator/OzaBagAdwin_1m8s.txt')

# %%
df_Hoeffding_SEA.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                    1000.000000                    1000.000000
# mean                   500500.000000                       4.108255
# std                    288819.436096                       2.918823
# min                      1000.000000                       0.026372
# 25%                    250750.000000                       1.550349
# 50%                    500500.000000                       3.597623
# 75%                    750250.000000                       6.471903
# max                   1000000.000000                      10.135188
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+03           1000.000000
# mean             2.934686e-07         500500.000000
# std              3.044072e-07         288819.436096
# min              1.282604e-11           1000.000000
# 25%              3.677683e-08         250750.000000
# 50%              1.744718e-07         500500.000000
# 75%              4.951872e-07         750250.000000
# max              1.058242e-06        1000000.000000
#
#        classifications correct (percent)  Kappa Statistic (percent)  \
# count                         1000.00000                1000.000000
# mean                            86.08860                  72.173585
# std                              3.31742                   6.640713
# min                             77.10000                  54.035631
# 25%                             83.90000                  67.697746
# 50%                             87.05000                  74.066117
# 75%                             88.70000                  77.409849
# max                             91.90000                  83.802721
#
#        Kappa Temporal Statistic (percent)  Kappa M Statistic (percent)  \
# count                         1000.000000                  1000.000000
# mean                            82.984629                    71.763160
# std                              4.145584                     6.728086
# min                             71.336761                    53.455285
# 25%                             80.189741                    67.215743
# 50%                             84.000112                    73.582973
# 75%                             86.220454                    77.086529
# max                             90.581395                    83.636364
#
#        model training instances  model serialized size (bytes)  \
# count               1000.000000                    1000.000000
# mean              500500.000000                  339440.528000
# std               288819.436096                  194333.519573
# min                 1000.000000                    1880.000000
# 25%               250750.000000                  172776.000000
# 50%               500500.000000                  350328.000000
# 75%               750250.000000                  495954.000000
# max              1000000.000000                  681496.000000
#
#        tree size (nodes)  tree size (leaves)  active learning leaves  \
# count        1000.000000         1000.000000             1000.000000
# mean          363.822000          182.411000              182.411000
# std           208.882705          104.441352              104.441352
# min             1.000000            1.000000                1.000000
# 25%           184.500000           92.750000               92.750000
# 50%           375.000000          188.000000              188.000000
# 75%           533.000000          267.000000              267.000000
# max           731.000000          366.000000              366.000000
#
#         tree depth  active leaf byte size estimate  \
# count  1000.000000                     1000.000000
# mean     11.918000                        1.733967
# std       2.635569                       54.832858
# min       0.000000                        0.000000
# 25%      11.000000                        0.000000
# 50%      13.000000                        0.000000
# 75%      14.000000                        0.000000
# max      15.000000                     1733.967213
#
#        inactive leaf byte size estimate  byte size estimate overhead
# count                            1000.0                  1000.000000
# mean                                0.0                     1.000074
# std                                 0.0                     0.002335
# min                                 0.0                     1.000000
# 25%                                 0.0                     1.000000
# 50%                                 0.0                     1.000000
# 75%                                 0.0                     1.000000
# max                                 0.0                     1.073844

# %%
df_kNN_SEA.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                    1000.000000                    1000.000000
# mean                   500500.000000                
# mean                            88.42930                  76.856308
# std                              1.93736                   3.883460
# min                             77.90000                  55.800000
# 25%                             87.70000                  75.392618
# 50%                             88.80000                  77.602285
# 75%                             89.60000                  79.200000
# max                             92.50000                  84.999760
#
#        Kappa Temporal Statistic (percent)  Kappa M Statistic (percent)  \
# count                         1000.000000                  1000.000000
# mean                            85.838542                    76.511323
# std                              2.545633                     3.954520
# min                             72.214941                    54.897959
# 25%                             84.716678                    75.000000
# 50%                             86.307301                    77.286392
# 75%                             87.409201                    78.947368
# max                             91.359447                    84.879032
#
#        model training instances  model serialized size (bytes)  \
# count               1000.000000                   1.000000e+03
# mean              500500.000000                   1.366229e+06
# std               288819.436096                   6.000066e+05
# min                 1000.000000                   1.101120e+05
# 25%               250750.000000                   9.668880e+05
# 50%               500500.000000                   1.373964e+06
# 75%               750250.000000                   1.812272e+06
# max              1000000.000000                   2.666040e+06
#
#                      ...                  [avg] active learning leaves  \
# count                ...                                   1000.000000
# mean                 ...                                     67.297700
# std                  ...                                     31.817993
# min                  ...                                      1.100000
# 25%                  ...                                     46.175000
# 50%                  ...                                     67.700000
# 75%                  ...                                     90.850000
# max                  ...                                    136.200000
#
#        [err] active learning leaves  [avg] tree depth  [err] tree depth  \
# count                   1000.000000       1000.000000       1000.000000
# mean                       8.904620          8.604500          0.432131
# std                        7.402138          2.107413          0.328374
# min                        0.100000          0.100000          0.000000
# 25%                        0.763763          7.600000          0.163299
# 50%                       10.375318          8.950000          0.394405
# 75%                       12.930713         10.000000          0.568372
# max                       20.471905         11.800000          1.832121
#
#        [avg] active leaf byte size estimate  \
# count                                1000.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
#        [err] active leaf byte size estimate  \
# count                                1000.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
#        [avg] inactive leaf byte size estimate  \
# count                                  1000.0
# mean                                      0.0
# std                                       0.0
# min                                       0.0
# 25%                                       0.0
# 50%                                       0.0
# 75%                                       0.0
# max                                       0.0
#
#        [err] inactive leaf byte size estimate  \
# count                                  1000.0
# mean                                      0.0
# std                                       0.0
# min                                       0.0
# 25%                                       0.0
# 50%                                       0.0
# 75%                                       0.0
# max                                       0.0
#
#        [avg] byte size estimate overhead  [err] byte size estimate overhead
# count                             1000.0                             1000.0
# mean                                 1.0                                0.0
# std                                  0.0                                0.0
# min                                  1.0                                0.0
# 25%                                  1.0                                0.0
# 50%                                  1.0                                0.0
# 75%                                  1.0                                0.0
# max                                  1.0                                0.0
#
# [8 rows x 29 columns]

# %%
# Plotando o gráfico do gerador SEAGenerator.
plt.figure(figsize=(20,10))
plt.plot(df_Hoeffding_SEA['learning evaluation instances'], df_Hoeffding_SEA['classifications correct (percent)'], label='HoeffdingTree')
plt.plot(df_Naive_SEA['learning evaluation instances'], df_Naive_SEA['classifications correct (percent)'], label='NaiveBayes')
plt.plot(df_kNN_SEA['learning evaluation instances'], df_kNN_SEA['classifications correct (percent)'], label='kNN')
plt.plot(df_Oza_SEA['learning evaluation instances'], df_Oza_SEA['classifications correct (percent)'], label='OzaBagAdwin')
plt.axvspan(180000, 220000, color='red', alpha=0.5)
plt.axvspan(380000, 420000, color='red', alpha=0.5)
plt.axvspan(580000, 620000, color='red', alpha=0.5)
plt.axvspan(780000, 820000, color='red', alpha=0.5)
plt.xlim(0, 1000000)

# Add the legend with some customizations.
legend = plt.legend(loc='lower left', shadow=True)

# The frame is matplotlib.patches.Rectangle instance surrounding the legend.
frame = legend.get_frame()
frame.set_facecolor('0.90')

# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
    
for label in legend.get_lines():
    label.set_linewidth(1.5)

# Plot chart.
plt.show()
